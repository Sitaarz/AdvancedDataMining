# %%
import pandas as pd
PATH_TO_DATA = "../../data/filtered_data_10000_rows_per_genre.csv"

# %%
df = pd.read_csv(PATH_TO_DATA)
# df.head()
df['dlugosc'] = df['plot'].str.len()
df['dlugosc'].mean()
# Out:
# np.float64(567.9716666666667)
